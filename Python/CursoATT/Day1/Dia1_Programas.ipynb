# %%
import math

dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
'para instalar librerías'
'pip libreria'
'o también, conda install libreria'
import sympy
import numpy
import os

'dir(numpy)'

'Ruta física de mi libería'
print(sympy, os.getcwd())
# Out:
# <module 'sympy' from 'C:\\Users\\ZayLJ\\anaconda3\\Lib\\site-packages\\sympy\\__init__.py'> C:\Users\ZayLJ

# %%
def saludar():
    print('Saludo')
    
saludar()
# Out:
# Saludo

# %%
'Ejercicios: Calcular 1- Área de Rectángulo 2- Área de Triángulo 3- Área Círculo 4 - Volumen Prisma Rectangular'
'5 - Grados de Co a Fo 6 - Grados de Fo a Co 7 - IVA de un Producto 8 - Sumar el IVA de un Producto'
'9 - Dado el honorario por hr de un trabajador , hacer una tabla de 0 a 40 hrs trabajadas '
'10 - Dada una poblacion inicial de bacterias y el factor de crecimiento, calcular la poblacion de 0 a 72 hrs'

import math

def areaRectangulo(base, altura):
    return base * altura

def areaTriangulo(base, altura):
    return (base*altura)/2

def areaCirculo(radio):
    return math.pi * (radio) ** 2

def volumenPrismaRectangular(largo, ancho, altura):
    return largo * ancho * altura

def C_a_F(gradCels):
    return gradCels*(9/5) + 32

def F_a_C(gradFahr):
    return (gradFahr - 32) * (5/9)

def calcIVA(importe):
    return importe * 0.16

def SumIVA(importe):
    return importe + calcIVA(importe)

def costoxhrRecurso(costo):
    
    for hr in range(1,41):
        print(hr,'hr : $', hr*costo)
        
def crecimientoBacterias(pBacterias, factCrec):
    
    for t in range(0,73):
        print(math.floor(pBacterias*math.exp(t*factCrec)))


'areaRectangulo(3, 4)'

'areaTriangulo(5,7)'

'areaCirculo(1)'

'volumenPrismaRectangular(3,3,3)'

'C_a_F(12)'

'F_a_C(32)'

'calcIVA(100)'

'SumIVA(100)'

'costoxhrRecurso(100)'

crecimientoBacterias(20,0.2)
# Out:
# 20
# 24
# 29
# 36
# 44
# 54
# 66
# 81
# 99
# 120
# 147
# 180
# 220
# 269
# 328
# 401
# 490
# 599
# 731
# 894
# 1091
# 1333
# 1629
# 1989
# 2430
# 2968
# 3625
# 4428
# 5408
# 6605
# 8068
# 9854
# 12036
# 14701
# 17956
# 21932
# 26788
# 32719
# 39963
# 48812
# 59619
# 72819
# 88941
# 108633
# 132684
# 162061
# 197942
# 241767
# 295295
# 360674
# 440529
# 538063
# 657192
# 802696
# 980416
# 1197482
# 1462608
# 1786434
# 2181955
# 2665047
# 3255095
# 3975783
# 4856032
# 5931171
# 7244348
# 8848267
# 10807298
# 13200064
# 16122595
# 19692182
# 24052085
# 29377283
# 35881495
